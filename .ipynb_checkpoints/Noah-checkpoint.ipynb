# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('HOUSE_precinct_general.csv')
df.columns
# Out:
# Index(['precinct', 'office', 'party_detailed', 'party_simplified', 'mode',
#        'votes', 'county_name', 'county_fips', 'jurisdiction_name',
#        'jurisdiction_fips', 'candidate', 'district', 'dataverse', 'year',
#        'stage', 'state', 'special', 'writein', 'state_po', 'state_fips',
#        'state_cen', 'state_ic', 'date', 'readme_check', 'magnitude'],
#       dtype='object')

# %%
df[['district', 'state', 'votes']].groupby(['district', 'state']).sum()
# Out:
#                                 votes
# district state
# 0        ALASKA                351982
#          DELAWARE              488270
#          DISTRICT OF COLUMBIA  326587
#          MONTANA               601509
#          NORTH DAKOTA          355598
# ...                               ...
# 49       CALIFORNIA            386506
# 50       CALIFORNIA            362390
# 51       CALIFORNIA            242437
# 52       CALIFORNIA            396495
# 53       CALIFORNIA            334858
#
# [435 rows x 1 columns]

# %%
reps = pd.read_csv('data/fivethirtyeight/rep_candidates.csv', encoding='ISO-8859-1')

# %%
reps
# Out:
#                    Candidate  Gender            Race 1 Race 2 Race 3  \
# 0       Aditya "A.D." Atholi    Male    Asian (Indian)    NaN    NaN
# 1               Joe McDaniel    Male             White    NaN    NaN
# 2            Nathaniel Moran    Male             White    NaN    NaN
# 3                 John Porro    Male             White    NaN    NaN
# 4               Dan Crenshaw    Male             White    NaN    NaN
# ...                      ...     ...               ...    ...    ...
# 1594         Karen Testerman  Female  Asian (Japanese)  White    NaN
# 1595         Allen R. Waters    Male             Black    NaN    NaN
# 1596           Allan W. Fung    Male   Asian (Chinese)    NaN    NaN
# 1597      Ashley Marie Kalus  Female             White    NaN    NaN
# 1598  Jonathan J. Riccitelli    Male             White    NaN    NaN
#
#      Incumbent Incumbent Challenger          State Primary Date  \
# 0           No                   No          Texas       3/1/22
# ...

# %%
pd.pivot(reps, index='2020 Election Stance', columns='Incumbent', values=')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/js/07cphsw10pv_zhnyn01xkt6w0000gn/T/ipykernel_8867/4152466358.py in <module>
# ----> 1 pd.pivot(reps, index='2020 Election Stance', columns='Incumbent')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517     return indexed.unstack(columns_listlike)
#     518
#     519
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in unstack(self, level, fill_value)
#    8322         from pandas.core.reshape.reshape import unstack
#    8323
# -> 8324         result = unstack(self, level, fill_value)
#    8325
#    8326         return result.__finalize__(self, method="unstack")
#
# ...

# %%
educ = pd.read_csv('educ.csv')
educ
# Out:
#             GEO_ID                                               NAME  \
# 0        Geography                               Geographic Area Name
# 1    5001800US0101  Congressional District 1 (118th Congress), Ala...
# 2    5001800US0102  Congressional District 2 (118th Congress), Ala...
# 3    5001800US0103  Congressional District 3 (118th Congress), Ala...
# 4    5001800US0104  Congressional District 4 (118th Congress), Ala...
# ..             ...                                                ...
# 433  5001800US5506  Congressional District 6 (118th Congress), Wis...
# 434  5001800US5507  Congressional District 7 (118th Congress), Wis...
# 435  5001800US5508  Congressional District 8 (118th Congress), Wis...
# 436  5001800US5600  Congressional District (at Large) (118th Congr...
# 437  5001800US7298  Resident Commissioner District (at Large) (118...
#
#                                         S1501_C01_001E  \
# 0    Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# ...

# %%
dems = pd.read_csv('data/fivethirtyeight/dem_candidates.csv')
reps = pd.read_csv('data/fivethirtyeight/rep_candidates.csv', encoding = 'ISO-8859-1')
dems.columns
# Out:
# Index(['Candidate', 'Gender', 'Race 1', 'Race 2', 'Race 3', 'Incumbent',
#        'Incumbent Challenger', 'State', 'Primary Date', 'Office', 'District',
#        'Primary Votes', 'Primary %', 'Primary Outcome', 'Runoff Votes',
#        'Runoff %', 'Runoff Outcome', 'EMILY's List', 'Justice Dems',
#        'Indivisible', 'PCCC', 'Our Revolution', 'Sunrise', 'Sanders', 'AOC',
#        'Party Committee'],
#       dtype='object')

# %%
dems.Incumbent.value_counts()
# Out:
# No     862
# Yes    215
# Name: Incumbent, dtype: int64

# %%
dems['IncumbentBin'] = dems['Incumbent'].map({'No': 0, 'Yes': 1})
reps['IncumbentBin'] = reps['Incumbent'].map({'No': 0, 'Yes': 1})
dems['Fullname'] = dems['State'] + dems['District']
reps['Fullname'] = reps['State'] + reps['District']

alls = pd.concat([dems, reps])
alls = alls[alls['Office'] == 'Representative']
incdists = alls[alls['Incumbent'] == 'Yes']['Fullname'].unique()
chadists = alls[alls['Incumbent'] == 'No']['Fullname'].unique()

incs = alls[alls['Fullname'].isin(incdists)]
chas = alls[alls['Fullname'].isin(chadists)]

inccounts = incs[['Fullname', 'Candidate']].groupby('Fullname').count()
chacounts = chas[['Fullname', 'Candidate']].groupby('Fullname').count()
inccounts['Type'] = 'Incumbent'
chacounts['Type'] = 'Challenger'

allcounts = pd.concat([inccounts, chacounts]).reset_index()

# %%
import seaborn as sns
# Out:
# <AxesSubplot:xlabel='Candidate', ylabel='Count'>

# %%
sns.histplot(inccounts, x='Candidate', stat='density')
# Out:
# <AxesSubplot:xlabel='Candidate', ylabel='Density'>

# %%
sns.histplot(chacounts, x='Candidate', stat='density')
# Out:
# <AxesSubplot:xlabel='Candidate', ylabel='Density'>

# %%
bins = np.arange(0, 24, 1)

sns.histplot(allcounts, x='Candidate', stat='density', hue='Type', bins=bins, palette='tab10', alpha=0.5, kde=True)
# Out:
# <AxesSubplot:xlabel='Candidate', ylabel='Density'>

# %%
allcounts
# Out:
#             Fullname  Candidate        Type
# 0           Alabama1          1   Incumbent
# 1           Alabama2          3   Incumbent
# 2           Alabama3          3   Incumbent
# 3           Alabama4          3   Incumbent
# 4           Alabama6          1   Incumbent
# ..               ...        ...         ...
# 777       Wisconsin5          2  Challenger
# 778       Wisconsin6          2  Challenger
# 779       Wisconsin7          3  Challenger
# 780       Wisconsin8          2  Challenger
# 781  WyomingAt-Large          8  Challenger
#
# [782 rows x 3 columns]
